# %% [markdown]
# # Importing required libraries

# %%
# !pip install keras_tuner
# Out:
# Requirement already satisfied: keras_tuner in /home/codespace/.python/current/lib/python3.12/site-packages (1.4.7)
# Requirement already satisfied: keras in /home/codespace/.local/lib/python3.12/site-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /home/codespace/.python/current/lib/python3.12/site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (2.1.0)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (0.0.8)
# Requirement already satisfied: h5py in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (3.12.1)
# Requirement already satisfied: optree in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in /home/codespace/.local/lib/python3.12/site-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->keras_tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->keras_tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->keras_tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from optree->keras->keras_tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich->keras->keras_tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/codespace/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import root_mean_squared_error, mean_squared_error
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta
from keras_tuner.tuners import RandomSearch,Hyperband
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import r2_score

# %% [markdown]
# # Data preprocessing and exploration

# %%
# importing the dataset
df=pd.read_csv('AAPL.csv')

# %%
# information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   object
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# preview of the data
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 1 2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2 2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 3 2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 4 2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 2006  24643000
# 2007  12119700
# 2008  23280300
# 2009  36566500
# 2010  36028600

# %%
# checking for null values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - There are no null values

# %%
df.select_dtypes(include=['number']).describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %% [markdown]
# **Data Describtion :-**
#
#     Date : Date of trading
#
#     Open : Price at which security first trades
#
#     High : Highest Price of the trading day
#
#     Low : Lowest Price of the trading day
#
#     Close : Last Price the stock traded during the trading day
#
#     Adj Close : Price that is adjusts Coroporate Actions on Closing Price
#
#     Volume : Number of Shares that changed hands during the trading day

# %%
df['month']=df['Date'].dt.month_name()
df['year']=df['Date'].dt.year
df['dayofweek']=df['Date'].dt.day_name()
df['quarter']=df['Date'].dt.quarter
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 1 2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2 2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 3 2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 4 2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100
#
#      month  year  dayofweek  quarter
# 0  January  2012    Tuesday        1
# 1  January  2012  Wednesday        1
# 2  January  2012   Thursday        1
# 3  January  2012     Friday        1
# 4  January  2012     Monday        1

# %%
plt.figure(figsize=(14,8))
for i,col in enumerate(df.columns[1:-4], 1):
    plt.subplot(2,3,i)
    sns.histplot(df[col], color='green')
    plt.title(f'{col}')
plt.tight_layout()
plt.show()

# %%
import matplotlib.dates as mdates
plt.figure(figsize=(14, 14))
for i, col in enumerate(df.columns[1:-4], 1):
    plt.subplot(6, 1, i)
    sns.lineplot(x=df['Date'], y=df[col], color='green')  
    plt.title(f'{col}')
    
    # Format the x-axis to show only years
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))


ax1 = plt.gca()
sns.lineplot(x='Date', y='Close', data=df, ax=ax1, color='blue', label='Closing Price')
ax1.set_ylabel('Closing Price')
ax1.set_xlabel('Date')


# Create the second axis for 'Volume'
ax2 = ax1.twinx()  
sns.lineplot(x='Date', y='Volume', data=df, ax=ax2, color='red', label='Volume')
ax2.set_ylabel('Volume')

plt.title('Closing Price and Volume')
plt.show()

# %% [markdown]
# **Plot inference**:As the closing price increases, the volume decreases, indicating that fewer shares are being traded

# %%
corr=df.iloc[:,1:-4].corr()

sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# - We can eliminate features like Open, Low, High, and Adj Close as they are highly multicollinear with Close.
# - We consider Close as our target variable since it represents the actual market price at which the stock was last traded during a given period, making it a key indicator for price trend analysis.

# %% [markdown]
# ## Filtering the data to closing price

# %%
sns.histplot(df['Close'],kde=True)
plt.title("Closing price distribution")
plt.show()

# %% [markdown]
# **Plot Inference:** Right skewed

# %%
sns.boxplot(df['Close'])
plt.title("Closing price boxplot")
plt.show()

# %%
print('Skewness of Distribution is ',df['Close'].skew())
print('Kurtosis of Distribution is ',df['Close'].kurtosis())
# Out:
# Skewness of Distribution is  0.7738383526895003
# Kurtosis of Distribution is  -0.15503801824484675

# %%
plt.figure(figsize=(8,8))
sns.boxplot(df,x='year', y='Close',color='green' )
plt.title('Box plot showing year-wise closing price')
plt.show()

# %%
columns=['dayofweek','month','quarter','year',]

plt.figure(figsize=(10,10))
for i,j in enumerate(columns,1):
    temp=df.groupby(j).agg({'Close':'mean'}).reset_index()
    temp = temp.sort_values(by="Close")
    plt.subplot(4,1,i)
    sns.barplot(temp,x=j,y='Close', color='lightgreen', width=0.6)
    plt.title(f"Closing price {j}-wise")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(df,x='year', y='Close',hue='month' )
plt.title('Clustered bar plot showing year-wise monthly closing price distribution')
plt.show()

# %% [markdown]
# - Outliers in 2012 and 2019 suggest volatile periods, while declines in 2013 and 2016 point to downturns or weaker investor sentiment.
# - The increasing trend in closing prices indicates a general growth in stock value over time.
# - Monday's consistently high closing prices and the end-of-month peaks reflect particular patterns in investor behavior, with higher activity at the start and end of the week and month.
# - The last quarter sees a notable rise in prices, likely driven by end-of-year market adjustments.
# - Overall, despite some volatility and occasional declines, the data shows an upward trend in stock prices, particularly towards the end of the analyzed period.

# %%
# Filtering out the closing price 
df1=df[['Close']]

df1['log_close']=np.log(df1['Close'])

# %%
plt.figure(figsize=(14,6))
sns.lineplot(df1['Close'], label='Original', color='skyblue')
df1['Close'][1:].rolling(7).mean().plot(label='Rolling Mean(7)', color='red')
df1['Close'][1:].rolling(30).mean().plot(label='Rolling Mean(30)', color='orange')
df1['Close'][1:].rolling(365).mean().plot(label='Rolling Mean(365)', color='green')
plt.ylabel('Closing price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - Original: The blue line represents the original closing price data. It shows significant fluctuations, indicating a high level of volatility.
#
# -
# Rolling Mean(7): The orange line represents a 7-day rolling mean. This line is smoother than the original data, suggesting a short-term trend. However, it still shows fluctuations, implying that the stock price changes frequently in the short term
#
# - Rolling Mean(30): The blue line represents a 30-day rolling mean. This line is smoother than the 7-day rolling mean but shows more fluctuations than the 365-day rolling mean, indicating a trend that exists between short-term and long-term.
#
# - Rolling Mean(365): The pink line represents a 365-day rolling mean. This line is smoother than the previous two, indicating a long-term trend. The smoothness suggests a yearly seasonality in the closing price.  e- .
#
# Therefore, the graph suggests that the closing price of the stock exhibits seasonality on a yearly basis. The long-term trend (represented by the 365-day rolling mean) is smoother than the short-term trends (represented by the 7 and 30-day rolling means), indicating that the stock price is more stable over a longer period.

# %%
result = seasonal_decompose(df1['Close'], model='multiplicative', period=365)

plt.figure(figsize=(14,8))
plt.suptitle('Seasonal Decomposition of Closing Prices for period=365', fontsize=16)
plt.subplot(4,1,1)
sns.lineplot(x=df1.index, y=df1['log_close'], color='blue')
plt.title('Original Series')
plt.ylabel('Price')

plt.subplot(4,1,2)
sns.lineplot(x=df1.index, y=result.trend, color='green')
plt.title('Trend')
plt.ylabel('Price')

plt.subplot(4,1,3)
sns.lineplot(x=df1.index, y=result.seasonal, color='brown')
plt.title('Seasonality')
plt.ylabel('Price')

plt.subplot(4,1,4)
sns.lineplot(x=df1.index, y=result.resid, color='orange')
plt.title('Resid')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# **stationarity:**
# The main conditions for stationarity are:
#
# * Constant Mean: The mean (average) of the series should remain stable over time.
# * Constant Variance: The spread (variance) of the series should not change   over time.
# * Constant Covariance: The relationship between values at different time lags should remain consistent.
#
# Hence, the series is non-stationary. Techniques like differencing or log transformation are often applied to make the data stationary before modeling.

# %%
# using augmented dickey fuller test for stationarity check
result = adfuller(df1['log_close'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -0.27401408154659834
# p-value: 0.929104933772776

# %%
# first order differencing as the data is non-stationary
df1['diff'] =df1['log_close']-df1['log_close'].shift(1)
df1.dropna(inplace=True)

# %%
result = seasonal_decompose(df1['diff'], model='add', period=365)

plt.figure(figsize=(14,8))
plt.suptitle('Seasonal Decomposition of Closing Prices for period=365', fontsize=16)
plt.subplot(4,1,1)
sns.lineplot(x=df1.index, y=df1['diff'], color='lightblue')
plt.title('Original Series')
plt.ylabel('Price')

plt.subplot(4,1,2)
sns.lineplot(x=df1.index, y=result.trend, color='green')
plt.title('Trend')
plt.ylabel('Price')

plt.subplot(4,1,3)
sns.lineplot(x=df1.index, y=result.seasonal, color='brown')
plt.title('Seasonality')
plt.ylabel('Price')

plt.subplot(4,1,4)
sns.lineplot(x=df1.index, y=result.resid, color='orange')
plt.title('Resid')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
result = adfuller(df1['diff'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {np.round(result[1],4)}')
# Out:
# ADF Statistic: -15.755566347955524
# p-value: 0.0

# %% [markdown]
# #### Now the series is stationary

# %%
df1.head()
# Out:
#        Close  log_close      diff
# 1  59.062859   4.078602  0.005360
# 2  59.718571   4.089643  0.011041
# 3  60.342857   4.100043  0.010400
# 4  60.247143   4.098455 -0.001587
# 5  60.462856   4.102029  0.003574

# %% [markdown]
# #### Plotting autocorrelation (acf) and partial autocorrelation plot (pacf) to choose p, q values

# %%
plt.figure(figsize=(14, 6))
# Autocorrelation Plot
plt.subplot(1, 2, 1)
plot_acf(df1['diff'], lags=40, ax=plt.gca()) 
plt.title('Autocorrelation Function (ACF)')

# Partial Autocorrelation Plot
plt.subplot(1, 2, 2)
plot_pacf(df1['diff'], lags=40, ax=plt.gca(), method='ywm') 
plt.title('Partial Autocorrelation Function (PACF)')
plt.tight_layout()
plt.show()

# %%
# autoregression order from pacf plot
q= 7
# moving-average order from acf plot
p= 7

# %%
# train and test split
train=df1.iloc[:-252]
# last year considering as test series without including weekends
test=df1.iloc[-252:]    

train.shape, test.shape
# Out:
# ((1758, 3), (252, 3))

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Arima Model
# - Best For: Non-seasonal data with trends.
# - Why: ARIMA models are widely used because they capture trends, lags, and relationships within the data through autoregression and moving averages. They’re very effective for stationary data or data that can be made stationary through differencing.
# - Limitations: ARIMA does not handle seasonality well without extensions like SARIMA (Seasonal ARIMA), which adds seasonal components.

# %% [markdown]
# #### finding the best value for (P,Q,D)

# %%
p_values=range(2,8)
q_values=range(2,8)
d_values=range(0,2)
for p in p_values:
    for q in q_values:
        for d in d_values:
            arima_model=ARIMA(train['diff'],order=(p,d,q))
            arima_model=arima_model.fit()
            forecast_steps = 252
            forecast = arima_model.forecast(steps=forecast_steps)
            forecast_org = forecast.cumsum() + df1['Close'].iloc[-252 - 1]
            print(f"{(p,d,q)} RMSE:",root_mean_squared_error(forecast_org,test['Close']))
# Out:
# (2, 0, 2) RMSE: 54.37032965266886
# (2, 1, 2) RMSE: 53.93793513013034
# (2, 0, 3) RMSE: 54.062423816464936
# (2, 1, 3) RMSE: 53.96435422881711
# (2, 0, 4) RMSE: 54.341871327477655
# (2, 1, 4) RMSE: 53.93820481912413
# (2, 0, 5) RMSE: 54.271777986761705
# (2, 1, 5) RMSE: 54.652524935155725
# (2, 0, 6) RMSE: 54.23936655999803
# (2, 1, 6) RMSE: 54.3785707529134
# (2, 0, 7) RMSE: 54.71049162740322
# (2, 1, 7) RMSE: 54.87515374709896
# (3, 0, 2) RMSE: 54.230668593238555
# (3, 1, 2) RMSE: 53.91954268402074
# (3, 0, 3) RMSE: 54.283932186507684
# (3, 1, 3) RMSE: 53.900474284030594
# (3, 0, 4) RMSE: 54.85084285430123
# (3, 1, 4) RMSE: 53.83551522661193
# (3, 0, 5) RMSE: 59.582443513818006
# (3, 1, 5) RMSE: 55.69614195557879
# (3, 0, 6) RMSE: 58.952956132095075
# (3, 1, 6) RMSE: 53.796225341588446
# (3, 0, 7) RMSE: 54.47620853410215
# (3, 1, 7) RMSE: 131.4590296236542
# (4, 0, 2) RMSE: 54.0318249515859
# (4, 1, 2) RMSE: 128.85219481318282
# (4, 0, 3) RMSE: 68.37564592492018
# (4, 1, 3) RMSE: 116.30012427378462
# (4, 0, 4) RMSE: 54.23015660472232
# (4, 1, 4) RMSE: 53.9952547967375
# (4, 0, 5) RMSE: 54.55705647453854
# (4, 1, 5) RMSE: 54.95049639305913
# (4, 0, 6) RMSE: 53.560470936512736
# (4, 1, 6) RMSE: 53.78641012455332
# (4, 0, 7) RMSE: 54.464610435582244
# (4, 1, 7) RMSE: 124.17388835794674
# (5, 0, 2) RMSE: 59.25800378503977
# (5, 1, 2) RMSE: 99.22269827362729
# (5, 0, 3) RMSE: 55.26177372172005
# (5, 1, 3) RMSE: 119.31605730241715
# (5, 0, 4) RMSE: 54.857573053967414
# (5, 1, 4) RMSE: 54.416964022313216
# (5, 0, 5) RMSE: 54.22475391881037
# (5, 1, 5) RMSE: 55.47863268802823
# (5, 0, 6) RMSE: 55.803665260566376
# (5, 1, 6) RMSE: 54.82269011215223
# (5, 0, 7) RMSE: 54.386834525588284
# (5, 1, 7) RMSE: 71.5406832178534
# (6, 0, 2) RMSE: 59.65086301163847
# (6, 1, 2) RMSE: 115.17512772267547
# (6, 0, 3) RMSE: 56.18051734366425
# (6, 1, 3) RMSE: 186.57790086911965
# (6, 0, 4) RMSE: 54.237828768166295
# (6, 1, 4) RMSE: 55.281071486863254
# (6, 0, 5) RMSE: 54.53721072409601
# (6, 1, 5) RMSE: 124.07058092285409
# (6, 0, 6) RMSE: 52.60784981276549
# (6, 1, 6) RMSE: 111.23484132194976
# (6, 0, 7) RMSE: 54.15694691103116
# (6, 1, 7) RMSE: 69.78896438845256
# (7, 0, 2) RMSE: 54.779875163833545
# (7, 1, 2) RMSE: 54.72846956328219
# (7, 0, 3) RMSE: 54.687380385333825
# (7, 1, 3) RMSE: 68.82113355906105
# (7, 0, 4) RMSE: 54.60191635087246
# (7, 1, 4) RMSE: 113.13466433237713
# (7, 0, 5) RMSE: 55.7057451354023
# (7, 1, 5) RMSE: 54.76798664092796
# (7, 0, 6) RMSE: 52.522263039982384
# (7, 1, 6) RMSE: 55.15431530436568
# (7, 0, 7) RMSE: 58.45115055302291
# (7, 1, 7) RMSE: 79.14134933411127

# %%
p=7
q=6
d=0 # as we already differenced the data
arima_model=ARIMA(train['diff'],order=(p,d,q))
arima_model=arima_model.fit()
print(arima_model.summary())
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                 1758
# Model:                 ARIMA(7, 0, 6)   Log Likelihood                4772.203
# Date:                Sat, 30 Nov 2024   AIC                          -9514.406
# Time:                        15:11:09   BIC                          -9432.327
# Sample:                             0   HQIC                         -9484.071
#                                - 1758
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.323      0.186      -0.000       0.001
# ar.L1         -0.9638      0.563     -1.713      0.087      -2.067       0.139
# ar.L2         -1.0658      0.597     -1.786      0.074      -2.235       0.104
# ar.L3         -0.4089      0.830     -0.493      0.622      -2.036       1.218
# ar.L4         -0.3851      0.831     -0.464      0.643      -2.013       1.243
# ar.L5         -0.3987      0.495     -0.805      0.421      -1.370       0.572
# ar.L6         -0.2829      0.343     -0.825      0.409      -0.955       0.389
# ar.L7          0.0479      0.044      1.096      0.273      -0.038       0.133
# ma.L1          0.9896      0.564      1.756      0.079      -0.115       2.094
# ma.L2          1.0550      0.603      1.749      0.080      -0.127       2.237
# ma.L3          0.3788      0.827      0.458      0.647      -1.242       2.000
# ma.L4          0.3798      0.819      0.464      0.643      -1.225       1.984
# ma.L5          0.3983      0.477      0.835      0.404      -0.536       1.333
# ma.L6          0.3259      0.319      1.021      0.307      -0.300       0.952
# sigma2         0.0003   5.33e-06     48.036      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):              1732.81
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.66   Skew:                            -0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast_steps = 252
pd.date_range(start=train.index[-1], periods=forecast_steps + 1, freq='B')[1:]
# Out:
# DatetimeIndex(['2018-12-31', '2019-01-01', '2019-01-02', '2019-01-03',
#                '2019-01-04', '2019-01-07', '2019-01-08', '2019-01-09',
#                '2019-01-10', '2019-01-11',
#                ...
#                '2019-12-04', '2019-12-05', '2019-12-06', '2019-12-09',
#                '2019-12-10', '2019-12-11', '2019-12-12', '2019-12-13',
#                '2019-12-16', '2019-12-17'],
#               dtype='datetime64[ns]', length=252, freq='B')

# %%
# forecasting for next 252 days
forecast_steps = 252
forecast = arima_model.forecast(steps=forecast_steps)

# reverse differencing
forecast_org = forecast.cumsum() + df1['Close'].iloc[-252 - 1]

forecast_index = pd.date_range(start=train.index[-1], periods=forecast_steps + 1, freq='B')[1:]
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# train predictions
train_predictions=arima_model.predict(start=0, end=1757)
# converting to original form
train_predictions_org=train_predictions.cumsum()+df1['Close'].iloc[0]
train_predictions_org
# Out:
# 1       59.063401
# 2       59.063989
# 3       59.064331
# 4       59.064383
# 5       59.064629
#           ...
# 1754    60.014865
# 1755    60.014513
# 1756    60.009463
# 1757    60.018458
# 1758    60.016129
# Name: predicted_mean, Length: 1758, dtype: float64

# %%
train['Close']
# Out:
# 1        59.062859
# 2        59.718571
# 3        60.342857
# 4        60.247143
# 5        60.462856
#            ...
# 1754    150.729996
# 1755    146.830002
# 1756    157.169998
# 1757    156.149994
# 1758    156.229996
# Name: Close, Length: 1758, dtype: float64

# %%
#RMSE 
arima_train_rmse=root_mean_squared_error(train['Close'],train_predictions_org )
arima_test_rmse=root_mean_squared_error(forecast_org,test['Close'] )
print("RMSE for train of ARIMA Model:",arima_train_rmse)
print("RMSE for test of ARIMA Model:",arima_test_rmse)
# Out:
# RMSE for train of ARIMA Model: 68.96372393027494
# RMSE for test of ARIMA Model: 61.73059920481023

# %%
plt.figure(figsize=(14, 7))
plt.plot(test['Close'], label='Actual Close Prices', color='blue')
plt.plot(forecast_index, forecast_org, label='One-Year Forecast', color='red')
plt.title('Stock Close Price Forecast for One Year')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# #### ARIMA model is doing very bad

# %% [markdown]
# ## SARIMA
# - Best For: Seasonal data with trends.
# - Why: SARIMA builds on ARIMA by adding seasonal elements, making it a robust choice for data with both trend and seasonal patterns (e.g., quarterly or monthly sales data).
# - Limitations: Model complexity increases with added parameters for seasonality. It also requires data to be well-behaved (not too noisy) and somewhat consistent in seasonal patterns

# %%
p=7
q=6
d=0 # as we already differenced the data
sarimax_model=SARIMAX(train['diff'],order=(p,d,q),seasonal_order=(p,d,q,12),disp=True)
sarimax_model=sarimax_model.fit()
sarimax_model.summary()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               diff   No. Observations:                 1758
# Model:             SARIMAX(7, 0, 6)x(7, 0, 6, 12)   Log Likelihood               -3611.388
# Date:                            Wed, 20 Nov 2024   AIC                           7276.776
# Time:                                    17:18:30   BIC                           7424.518
# Sample:                                         0   HQIC                          7331.378
#                                            - 1758
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7704      0.220     -3.509      0.000      -1.201      -0.340
# ar.L2         -0.9348      0.343     -2.727      0.006      -1.606      -0.263
# ar.L3         -0.0642      0.463     -0.139      0.890      -0.971       0.843
# ar.L4          0.0890      0.429      0.208      0.836      -0.752       0.930
# ar.L5          0.3751      0.282      1.331      0.183      -0.177       0.927
# ar.L6         -0.0410      0.161     -0.255      0.799      -0.357       0.275
# ar.L7          0.1151      0.024      4.877      0.000       0.069       0.161
# ma.L1          0.8111      0.222      3.649      0.000       0.375       1.247
# ma.L2          0.9312      0.350      2.661      0.008       0.245       1.617
# ma.L3          0.0407      0.474      0.086      0.931      -0.887       0.969
# ma.L4         -0.1163      0.435     -0.268      0.789      -0.968       0.736
# ma.L5         -0.3656      0.280     -1.307      0.191      -0.914       0.183
# ma.L6          0.0756      0.164      0.460      0.645      -0.246       0.397
# ar.S.L12      -0.6627      1.282     -0.517      0.605      -3.175       1.849
# ar.S.L24      -0.3664      0.344     -1.064      0.287      -1.041       0.309
# ar.S.L36      -0.0345      0.283     -0.122      0.903      -0.589       0.520
# ar.S.L48       0.6267      0.177      3.541      0.000       0.280       0.974
# ar.S.L60       0.7960      0.847      0.940      0.347      -0.863       2.455
# ar.S.L72       0.4904      0.644      0.761      0.447      -0.773       1.753
# ar.S.L84      -0.0028      0.051     -0.056      0.955      -0.102       0.097
# ma.S.L12       0.6677      1.277      0.523      0.601      -1.835       3.171
# ma.S.L24       0.3233      0.350      0.924      0.356      -0.363       1.009
# ma.S.L36       0.0048      0.237      0.020      0.984      -0.459       0.469
# ma.S.L48      -0.6165      0.172     -3.579      0.000      -0.954      -0.279
# ma.S.L60      -0.8076      0.816     -0.990      0.322      -2.406       0.791
# ma.S.L72      -0.4808      0.672     -0.715      0.474      -1.798       0.837
# sigma2         3.5495      0.073     48.395      0.000       3.406       3.693
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2461.13
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.31   Skew:                            -0.31
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
forecast=sarimax_model.forecast(steps=252)
forecast_org= forecast.cumsum() + df1['Close'].iloc[-252-1]
forecast_index= pd.date_range(start=train.index[-1],periods=forecast_steps+1,freq='B')[1:]
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# train predictions
train_predictions=sarimax_model.predict(start=0, end=1757)
train_predictions_org=train_predictions.cumsum()+df1['Close'].iloc[0]

# RMSE
sarima_train_rmse=root_mean_squared_error(train['Close'],train_predictions_org )
sarima_test_rmse=root_mean_squared_error(forecast_org,test['Close'] )
print("RMSE for train of ARIMA Model:",sarima_train_rmse)
print("RMSE for test of ARIMA Model:",sarima_test_rmse)
# Out:
# RMSE for train of ARIMA Model: 79.59609249194001
# RMSE for test of ARIMA Model: 65.33441278105134

# %%
plt.figure(figsize=(12,6))
plt.plot(test['Close'],label='Actual Close Prices',color='blue')
plt.plot(forecast_index,forecast_org,label='One-Year Forecast',color='red')
plt.title('Stock Close Price Forecast for One Year')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# #### SARIMAX is also doing bad

# %% [markdown]
# ## Exponential smoothing:
# - Best For: Data with seasonality, trend, and irregular fluctuations.
# - Why: Exponential smoothing methods like Holt-Winters use weighted averages to give recent data more importance. This can quickly adjust to changes and capture seasonality and trend without overfitting.
# - Limitations: Exponential smoothing doesn’t work well for long-term forecasts with complex seasonality. It also assumes seasonal patterns are constant over time.

# %%
# data must be positive for ExSmoothing
train['diff_positive'] = train['diff'] + abs(train['diff'].min()) + 1

# %%
ets_model=ExponentialSmoothing(train['diff'],trend='add',seasonal='add',
                                seasonal_periods=30).fit()
ets_model.summary()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                     diff   No. Observations:                 1758
# Model:             ExponentialSmoothing   SSE                           6396.580
# Optimized:                         True   AIC                           2338.609
# Trend:                         Additive   BIC                           2524.655
# Seasonal:                      Additive   AICC                          2340.157
# Seasonal Periods:                    30   Date:                 Wed, 20 Nov 2024
# Box-Cox:                          False   Time:                         13:04:54
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level              5.0004e-08                alpha                 True
# smoothing_trend              1.0622e-12                 beta                 True
# smoothing_seasonal           3.5105e-08                gamma                 True
# initial_level                 0.0918471                  l.0                 True
# initial_trend               -3.1304e-05                  b.0                 True
# initial_seasons.0             0.1752894                  s.0                 True
# initial_seasons.1            -0.1835160                  s.1                 True
# initial_seasons.2             0.0950447                  s.2                 True
# initial_seasons.3            -0.3421102                  s.3                 True
# initial_seasons.4             0.1190723                  s.4                 True
# initial_seasons.5            -0.0180704                  s.5                 True
# initial_seasons.6            -0.1250732                  s.6                 True
# initial_seasons.7             0.1806945                  s.7                 True
# initial_seasons.8            -0.0241885                  s.8                 True
# initial_seasons.9            -0.0630682                  s.9                 True
# initial_seasons.10           -0.1272439                 s.10                 True
# initial_seasons.11           -0.2695715                 s.11                 True
# initial_seasons.12           -0.0253389                 s.12                 True
# initial_seasons.13           -0.0292576                 s.13                 True
# initial_seasons.14            0.3205459                 s.14                 True
# initial_seasons.15            0.2520671                 s.15                 True
# initial_seasons.16           -0.1000474                 s.16                 True
# initial_seasons.17            0.4577593                 s.17                 True
# initial_seasons.18           -0.2637776                 s.18                 True
# initial_seasons.19           -0.2311678                 s.19                 True
# initial_seasons.20           -0.1019247                 s.20                 True
# initial_seasons.21           -0.3049983                 s.21                 True
# initial_seasons.22           -0.1833021                 s.22                 True
# initial_seasons.23           -0.0252539                 s.23                 True
# initial_seasons.24            0.0795379                 s.24                 True
# initial_seasons.25            0.3460027                 s.25                 True
# initial_seasons.26            0.1306816                 s.26                 True
# initial_seasons.27            0.1078750                 s.27                 True
# initial_seasons.28           -0.0029805                 s.28                 True
# initial_seasons.29           -0.1157987                 s.29                 True
# ---------------------------------------------------------------------------------
# """

# %%
forecast_steps=252
forecast=ets_model.forecast(steps=252)
forecast_org= forecast.cumsum() + df1['Close'].iloc[-252-1]
forecast_index= pd.date_range(start=train.index[-1],periods=forecast_steps+1,freq='B')[1:]
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
train_predictions=ets_model.predict(start=0, end=1757)
train_predictions_org=train_predictions.cumsum()+df1['Close'].iloc[0]

# RMSE
ets_train_rmse=root_mean_squared_error(train['Close'],train_predictions_org )
ets_test_rmse=root_mean_squared_error(forecast_org,test['Close'] )
print("RMSE for train of ets Model:",ets_train_rmse)
print("RMSE for test of ets Model:",ets_test_rmse)
# Out:
# RMSE for train of ets Model: 23.180178899643263
# RMSE for test of ets Model: 65.33441278105134

# %%
plt.figure(figsize=(14, 7))
plt.plot(test['Close'], label='Actual Close Prices', color='blue')
plt.plot(forecast_index, forecast_org, label='One-Year Forecast', color='red')
plt.title('Stock Close Price Forecast for One Year')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# #### Holt winter's Exponential smoothing is giving very bad results

# %% [markdown]
# ## LSTM (Long Short-Term Memory) Networks
# - Best For: Complex, non-linear data with long-range dependencies.
# - Why: LSTMs are a type of recurrent neural network (RNN) that can capture long-term dependencies and complex patterns, making them highly effective for large, high-dimensional datasets or very volatile data (e.g., stock price data).
# - Limitations: They are computationally intensive, require a large amount of data, and can be prone to overfitting if not regularized well.

# %%
# split the data into train and test
train=df1['Close'][:-252].values
# last one year exlcluding weekends considered as test
test=df1['Close'][-252:].values

# %%
train.shape, test.shape
# Out:
# ((1758,), (252,))

# %% [markdown]
# - LSTMs require input data in sequential form, typically as a sliding window of past values to predict future values.
# -  For example, to predict the next day’s price, create sequences with a defined window (e.g., 60 past time steps to predict the next value).
# -  if we give past 60 value as sequential input then these will not be included in the output set
# -  from 60th value of the training data to the end would be the output set
# -  len(train)-window_size would be the size of the input set and output set

# %%
# Normalizing the data , before normalizing reshaping the data as the scaler needs 2D data
scaler=MinMaxScaler()
train_scaled=scaler.fit_transform(train.reshape(-1,1))
test_scaled=scaler.transform(test.reshape(-1,1))

# %%
# function to form an input (sequential form) and output set
def create_dataset(data, time_step=1):
    x, y = [], []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i])   # past 60 steps
        y.append(data[i]) 
    return np.array(x), np.array(y)

# %%
# timestep or window size
time_step = 90

# calling the function and storing the x and y values
train_x, train_y = create_dataset(train_scaled, time_step)
test_x,test_y=create_dataset(test_scaled, time_step)

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((1668, 90, 1), (1668, 1), (162, 90, 1), (162, 1))

# %%
with open('test_x','wb') as file:
    pickle.dump(test_x,file)

# %% [markdown]
# ### Hyperparameter tuning

# %%
#Define the model-building function
def build_model(hp):
    model = Sequential()
    # Input layer with first LSTM
    model.add(LSTM(50, return_sequences=True, input_shape=(60, 1),kernel_regularizer=regularizers.l2(0.01)))
    reg_strength = hp.Choice("reg", [0.01, 0.001, 0.02])
    # Additional LSTM layers with hyperparameters for units and dropout
    for i in range(hp.Int('num_layers', 1, 4)):  
        model.add(LSTM(units=hp.Choice('units', [30, 50, 100, 150]), return_sequences=True,kernel_regularizer=regularizers.l2(reg_strength) ))
        model.add(Dropout(hp.Float('drop', 0.1, 0.5, step=0.1))) 
    # Output layer
    model.add(Dense(1))
    
    learning_rate = hp.Choice('lr', [0.001, 0.01, 0.1])
    
    # Select optimizer based on string, then apply chosen learning rate
    optimizer_choice = hp.Choice('optimizer', ['adam', 'sgd', 'adadelta'])
    if optimizer_choice == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_choice == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer_choice == 'adadelta':
        optimizer = Adadelta(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# %%
# Initialize the RandomSearch tuner
tuner=RandomSearch(build_model,objective='val_loss', max_trials=10, directory='my_dir',project_name='keras-tuner-train-data')

# hyperparameter search
tuner.search(train_x,train_y, validation_data=(test_x,test_y),epochs=20)
# Out:
# Trial 10 Complete [00h 02m 56s]
# val_loss: 0.3147001564502716
#
# Best val_loss So Far: 0.0444587767124176
# Total elapsed time: 00h 38m 55s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'reg': 0.001,
#  'num_layers': 1,
#  'units': 50,
#  'drop': 0.30000000000000004,
#  'lr': 0.01,
#  'optimizer': 'adam'}

# %%
# final model build
best_model=Sequential()
best_model.add(LSTM(50, return_sequences=True, input_shape=(90, 1),kernel_regularizer=regularizers.l2(0.01)))
best_model.add(Dropout(0.3))
best_model.add(LSTM(50, return_sequences=False, kernel_regularizer=regularizers.l2(0.001)))
best_model.add(Dropout(0.3))

best_model.add(Dense(1))

optimizer = Adam(learning_rate=0.01)
best_model.compile(optimizer=optimizer, loss='mean_squared_error')


#lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
best_model.fit(train_x, train_y, validation_data=(test_x, test_y), 
                epochs=50, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 121ms/step - loss: 0.0649 - val_loss: 0.0108
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0104 - val_loss: 0.0073
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0063 - val_loss: 0.0110
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0051 - val_loss: 0.0560
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0105 - val_loss: 0.0136
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0044 - val_loss: 0.0094
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0037 - val_loss: 0.0102
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0038 - val_loss: 0.0047

# %%
# predictions 
train_pred=best_model.predict(train_x)
test_pred=best_model.predict(test_x)
train_pred
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# array([[0.12041157],
#        [0.11889029],
#        [0.1172168 ],
#        ...,
#        [0.64640176],
#        [0.63857293],
#        [0.62971056]], dtype=float32)

# %%
train_y
# Out:
# array([[0.13589579],
#        [0.13180328],
#        [0.12605756],
#        ...,
#        [0.57510775],
#        [0.56932147],
#        [0.56977531]])

# %%
# reverse scaling the prediction values
train_pred_org=scaler.inverse_transform(train_pred)
test_pred_org=scaler.inverse_transform(test_pred)

# %%
# prediction in original form
train_pred_org
# Out:
# array([[ 77.01615 ],
#        [ 76.747986],
#        [ 76.45298 ],
#        ...,
#        [169.7377  ],
#        [168.35764 ],
#        [166.79538 ]], dtype=float32)

# %%
# original values
train[90:].reshape(-1,1)
# Out:
# array([[ 79.745712],
#        [ 79.024284],
#        [ 78.011429],
#        ...,
#        [157.169998],
#        [156.149994],
#        [156.229996]])

# %%
lstm_train_rmse=root_mean_squared_error(train[90:], train_pred_org)
lstm_test_rmse=root_mean_squared_error(test[90:], test_pred_org)
print("Train RMSE:",lstm_train_rmse)
print("Test RMSE:",lstm_test_rmse)
# Out:
# Train RMSE: 6.499350805355338
# Test RMSE: 10.075298177539848

# %%
# from 2D to 1D
train_pred_org.ravel().shape
# Out:
# (1668,)

# %%
plt.figure(figsize=(14,6))
sns.lineplot(y=train[90:],x=range(len(train[90:])), label='Actual_value', color='lightblue')
sns.lineplot(y=train_pred_org.ravel(),x=range(len(train_pred_org)), label='Predicted_value', color='brown')
plt.title('Trainset prediction analysis')
plt.legend()
plt.show()

# %%
test[90:].shape,test_pred_org.shape
# Out:
# ((162,), (162, 1))

# %%
plt.figure(figsize=(14,6))
sns.lineplot(y=test[90:],x=range(len(test[90:])), label='Actual_value', color='lightblue')
sns.lineplot(y=test_pred_org.ravel(),x=range(len(test_pred_org)), label='Predicted_value', color='brown')
plt.title('Testset prediction analysis')
plt.legend()
plt.show()

# %%
# Analysis of RMSE values of different models
models=['Arima','Sarima','ExponentialS','LSTM']
trainRmse=[arima_train_rmse, sarima_train_rmse,ets_train_rmse, lstm_train_rmse]
testRmse=[arima_test_rmse,sarima_test_rmse,ets_test_rmse, lstm_test_rmse]
Models_rmse=pd.DataFrame({'TrainRMSE':trainRmse, 'TestRMSE':testRmse}, index=models)
Models_rmse
# Out:
#               TrainRMSE   TestRMSE
# Arima         19.468333  52.522263
# Sarima        79.596092  65.334413
# ExponentialS  23.180179  65.334413
# LSTM          11.646511  11.434510

# %%
Models_rmse.plot(kind='bar',figsize=(14,5),colormap='Paired')
plt.xticks(rotation=360)
plt.tight_layout()
plt.title('Models RMSE Analysis')
plt.show()

# %%
df1['Close']
# Out:
# Date
# 2012-01-04     59.062859
# 2012-01-05     59.718571
# 2012-01-06     60.342857
# 2012-01-09     60.247143
# 2012-01-10     60.462856
#                  ...
# 2019-12-23    284.000000
# 2019-12-24    284.269989
# 2019-12-26    289.910004
# 2019-12-27    289.799988
# 2019-12-30    291.519989
# Name: Close, Length: 2010, dtype: float64

# %% [markdown]
# # Final stacked LSTM model on complete data

# %%
# function to form an input (sequential form) and output set
def create_dataset(data, time_step=1):
    x, y = [], []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i])   # past 60 steps
        y.append(data[i]) 
    return np.array(x), np.array(y)

# %%
# transforming the original data
time_step=365
data_x, data_y = create_dataset(df1['log_close'], time_step)
scaler_x=MinMaxScaler()
scaler_y=MinMaxScaler()
X=scaler_x.fit_transform(data_x)
Y=scaler_y.fit_transform(data_y.reshape(-1,1))

X_scaled= X.reshape(X.shape[0], X.shape[1], 1)
X_scaled.shape, Y.shape
# Out:
# ((1646, 365, 1), (1646, 1))

# %%
X_scaled
# Out:
# array([[[0.03623281],
#         [0.03999288],
#         [0.04773836],
#         ...,
#         [0.22165772],
#         [0.27060723],
#         [0.26831492]],
#
#        [[0.03999288],
#         [0.04773836],
#         [0.05503401],
#         ...,
#         [0.27387215],
#         [0.26831492],
#         [0.26360363]],
#
#        [[0.04773836],
#         [0.05503401],
#         [0.05392037],
#         ...,
#         [0.27155219],
#         [0.26360363],
#         [0.24415522]],
#
#        ...,
#
#        [[0.91538057],
#         [0.92718331],
#         [0.94076708],
#         ...,
#         [0.98947581],
#         [0.98750206],
#         [0.98807865]],
#
#        [[0.92718331],
#         [0.94076708],
#         [0.94070128],
#         ...,
#         [0.99941645],
#         [0.98807865],
#         [1.        ]],
#
#        [[0.94076708],
#         [0.94070128],
#         [0.94368844],
#         ...,
#         [1.        ],
#         [1.        ],
#         [0.99976968]]])

# %% [markdown]
# ### Hyperparameter tuning for best values:

# %%
# Initialize the RandomSearch tuner
tuner=RandomSearch(build_model,objective='val_loss', max_trials=10, directory='my_dir',project_name='keras-tuner-complete-data')

# hyperparameter search
tuner.search(X_scaled,Y, validation_split=0.3,epochs=30)
# Out:
# Reloading Tuner from my_dir\keras-tuner-complete-data\tuner0.json

# %%
tuner.results_summary()

# %%
# best hyperparameters
tuner.get_best_hyperparameters()[0].values
# Out:
# {'reg': 0.001,
#  'num_layers': 4,
#  'units': 150,
#  'drop': 0.5,
#  'lr': 0.001,
#  'optimizer': 'adam'}

# %% [markdown]
# ### Although the hyperparameter tuning yielded good scores, the model struggled to generalize the patterns, learning the noise and minor fluctuations, leading to overfitting. Instead, we manually tested different hyperparameters with a higher number of epochs to improve the model’s ability to generalize.

# %%
# final model build
final_model=Sequential()
final_model.add(LSTM(30, return_sequences=True, input_shape=(365, 1),kernel_regularizer=regularizers.l2(0.1)))
final_model.add(Dropout(0.5))
final_model.add(LSTM(30, return_sequences=False, kernel_regularizer=regularizers.l2(0.1)))
final_model.add(Dropout(0.5))

final_model.add(Dense(1))

optimizer = Adam(learning_rate=0.00001)
final_model.compile(optimizer=optimizer, loss='mean_squared_error')


#early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True) callbacks=[early_stopping]
final_model.fit(X_scaled, Y, validation_split=0.3, shuffle=False,
                epochs=500 )
# Out:
# Epoch 1/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 32s 636ms/step - loss: 5.0610 - val_loss: 5.4982
# Epoch 2/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 583ms/step - loss: 5.0295 - val_loss: 5.4503
# Epoch 3/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 577ms/step - loss: 4.9968 - val_loss: 5.4042
# Epoch 4/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 44s 653ms/step - loss: 4.9708 - val_loss: 5.3590
# Epoch 5/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 600ms/step - loss: 4.9413 - val_loss: 5.3146
# Epoch 6/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 594ms/step - loss: 4.9127 - val_loss: 5.2708
# Epoch 7/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 479ms/step - loss: 4.8813 - val_loss: 5.2273
# Epoch 8/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 562ms/step - loss: 4.8531 - val_loss: 5.1845
# Epoch 9/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 556ms/step - loss: 4.8257 - val_loss: 5.1423
# Epoch 10/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 516ms/step - loss: 4.7961 - val_loss: 5.1003
# Epoch 11/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 22s 563ms/step - loss: 4.7706 - val_loss: 5.0586
# Epoch 12/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 541ms/step - loss: 4.7434 - val_loss: 5.0174
# Epoch 13/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 534ms/step - loss: 4.7157 - val_loss: 4.9766
# Epoch 14/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 566ms/step - loss: 4.6888 - val_loss: 4.9363
# Epoch 15/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 564ms/step - loss: 4.6602 - val_loss: 4.8964
# Epoch 16/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 22s 604ms/step - loss: 4.6348 - val_loss: 4.8567
# Epoch 17/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 41s 600ms/step - loss: 4.6067 - val_loss: 4.8177
# Epoch 18/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 32s 350ms/step - loss: 4.5806 - val_loss: 4.7791
# Epoch 19/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 433ms/step - loss: 4.5552 - val_loss: 4.7408
# Epoch 20/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 23s 505ms/step - loss: 4.5292 - val_loss: 4.7030
# Epoch 21/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 435ms/step - loss: 4.5054 - val_loss: 4.6657
# Epoch 22/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 444ms/step - loss: 4.4801 - val_loss: 4.6288
# Epoch 23/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 432ms/step - loss: 4.4531 - val_loss: 4.5929
# Epoch 24/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 469ms/step - loss: 4.4281 - val_loss: 4.5576
# Epoch 25/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 555ms/step - loss: 4.4046 - val_loss: 4.5229
# Epoch 26/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - loss: 4.3798 - val_loss: 4.4888
# Epoch 27/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 469ms/step - loss: 4.3563 - val_loss: 4.4557
# Epoch 28/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 430ms/step - loss: 4.3321 - val_loss: 4.4233
# Epoch 29/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 446ms/step - loss: 4.3085 - val_loss: 4.3915
# Epoch 30/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 598ms/step - loss: 4.2851 - val_loss: 4.3605
# Epoch 31/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 43s 647ms/step - loss: 4.2619 - val_loss: 4.3304
# Epoch 32/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 23s 636ms/step - loss: 4.2379 - val_loss: 4.3011
# Epoch 33/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 532ms/step - loss: 4.2166 - val_loss: 4.2729
# Epoch 34/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 537ms/step - loss: 4.1940 - val_loss: 4.2450
# Epoch 35/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 441ms/step - loss: 4.1711 - val_loss: 4.2178
# Epoch 36/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 574ms/step - loss: 4.1498 - val_loss: 4.1910
# Epoch 37/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 469ms/step - loss: 4.1267 - val_loss: 4.1650
# Epoch 38/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 423ms/step - loss: 4.1054 - val_loss: 4.1397
# Epoch 39/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 25s 548ms/step - loss: 4.0831 - val_loss: 4.1151
# Epoch 40/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 398ms/step - loss: 4.0611 - val_loss: 4.0907
# Epoch 41/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 535ms/step - loss: 4.0401 - val_loss: 4.0664
# Epoch 42/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 589ms/step - loss: 4.0169 - val_loss: 4.0422
# Epoch 43/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 42s 595ms/step - loss: 3.9963 - val_loss: 4.0185
# Epoch 44/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 42s 622ms/step - loss: 3.9735 - val_loss: 3.9951
# Epoch 45/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 559ms/step - loss: 3.9523 - val_loss: 3.9729
# Epoch 46/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 557ms/step - loss: 3.9312 - val_loss: 3.9504
# Epoch 47/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 478ms/step - loss: 3.9104 - val_loss: 3.9284
# Epoch 48/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 427ms/step - loss: 3.8876 - val_loss: 3.9067
# Epoch 49/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step - loss: 3.8673 - val_loss: 3.8847
# Epoch 50/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 23s 497ms/step - loss: 3.8467 - val_loss: 3.8629
# Epoch 51/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 16s 462ms/step - loss: 3.8255 - val_loss: 3.8411
# Epoch 52/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 451ms/step - loss: 3.8045 - val_loss: 3.8202
# Epoch 53/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 453ms/step - loss: 3.7838 - val_loss: 3.7992
# Epoch 54/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 24s 544ms/step - loss: 3.7625 - val_loss: 3.7787
# Epoch 55/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 470ms/step - loss: 3.7424 - val_loss: 3.7581
# Epoch 56/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 515ms/step - loss: 3.7225 - val_loss: 3.7370
# Epoch 57/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 519ms/step - loss: 3.7012 - val_loss: 3.7162
# Epoch 58/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 521ms/step - loss: 3.6807 - val_loss: 3.6959
# Epoch 59/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 542ms/step - loss: 3.6605 - val_loss: 3.6752
# Epoch 60/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 538ms/step - loss: 3.6402 - val_loss: 3.6542
# Epoch 61/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 554ms/step - loss: 3.6193 - val_loss: 3.6336
# Epoch 62/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 522ms/step - loss: 3.6001 - val_loss: 3.6130
# Epoch 63/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 539ms/step - loss: 3.5803 - val_loss: 3.5937
# Epoch 64/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 20s 530ms/step - loss: 3.5599 - val_loss: 3.5741
# Epoch 65/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 22s 604ms/step - loss: 3.5398 - val_loss: 3.5542
# Epoch 66/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 477ms/step - loss: 3.5204 - val_loss: 3.5343
# Epoch 67/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - loss: 3.5023 - val_loss: 3.5142
# Epoch 68/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 404ms/step - loss: 3.4814 - val_loss: 3.4942
# Epoch 69/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 496ms/step - loss: 3.4622 - val_loss: 3.4742
# Epoch 70/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 22s 529ms/step - loss: 3.4438 - val_loss: 3.4545
# Epoch 71/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 23s 589ms/step - loss: 3.4243 - val_loss: 3.4354
# Epoch 72/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 324ms/step - loss: 3.4042 - val_loss: 3.4152
# Epoch 73/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 3.3860 - val_loss: 3.3959
# Epoch 74/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 249ms/step - loss: 3.3658 - val_loss: 3.3766
# Epoch 75/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - loss: 3.3462 - val_loss: 3.3574
# Epoch 76/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - loss: 3.3281 - val_loss: 3.3382
# Epoch 77/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 221ms/step - loss: 3.3096 - val_loss: 3.3190
# Epoch 78/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 3.2906 - val_loss: 3.3004
# Epoch 79/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - loss: 3.2722 - val_loss: 3.2808
# Epoch 80/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 3.2543 - val_loss: 3.2619
# Epoch 81/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 202ms/step - loss: 3.2352 - val_loss: 3.2434
# Epoch 82/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - loss: 3.2166 - val_loss: 3.2244
# Epoch 83/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 3.1987 - val_loss: 3.2057
# Epoch 84/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 3.1794 - val_loss: 3.1873
# Epoch 85/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 3.1619 - val_loss: 3.1695
# Epoch 86/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - loss: 3.1437 - val_loss: 3.1513
# Epoch 87/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 3.1257 - val_loss: 3.1325
# Epoch 88/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 3.1074 - val_loss: 3.1131
# Epoch 89/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 190ms/step - loss: 3.0901 - val_loss: 3.0961
# Epoch 90/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 3.0717 - val_loss: 3.0794
# Epoch 91/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 3.0536 - val_loss: 3.0618
# Epoch 92/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 3.0365 - val_loss: 3.0435
# Epoch 93/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 3.0182 - val_loss: 3.0252
# Epoch 94/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 3.0010 - val_loss: 3.0071
# Epoch 95/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 2.9852 - val_loss: 2.9890
# Epoch 96/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.9656 - val_loss: 2.9714
# Epoch 97/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 2.9490 - val_loss: 2.9539
# Epoch 98/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 225ms/step - loss: 2.9312 - val_loss: 2.9366
# Epoch 99/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 2.9147 - val_loss: 2.9191
# Epoch 100/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 2.8974 - val_loss: 2.9015
# Epoch 101/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - loss: 2.8814 - val_loss: 2.8849
# Epoch 102/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - loss: 2.8632 - val_loss: 2.8672
# Epoch 103/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.8462 - val_loss: 2.8502
# Epoch 104/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 2.8293 - val_loss: 2.8325
# Epoch 105/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 2.8126 - val_loss: 2.8158
# Epoch 106/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - loss: 2.7957 - val_loss: 2.7985
# Epoch 107/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 2.7790 - val_loss: 2.7819
# Epoch 108/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - loss: 2.7630 - val_loss: 2.7655
# Epoch 109/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 2.7469 - val_loss: 2.7497
# Epoch 110/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step - loss: 2.7304 - val_loss: 2.7325
# Epoch 111/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 225ms/step - loss: 2.7138 - val_loss: 2.7151
# Epoch 112/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 2.6977 - val_loss: 2.6987
# Epoch 113/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - loss: 2.6811 - val_loss: 2.6830
# Epoch 114/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - loss: 2.6656 - val_loss: 2.6680
# Epoch 115/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 2.6490 - val_loss: 2.6517
# Epoch 116/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 220ms/step - loss: 2.6324 - val_loss: 2.6349
# Epoch 117/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 2.6170 - val_loss: 2.6191
# Epoch 118/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 214ms/step - loss: 2.6009 - val_loss: 2.6033
# Epoch 119/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 2.5851 - val_loss: 2.5869
# Epoch 120/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 2.5699 - val_loss: 2.5705
# Epoch 121/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 2.5548 - val_loss: 2.5536
# Epoch 122/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - loss: 2.5387 - val_loss: 2.5382
# Epoch 123/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 2.5223 - val_loss: 2.5216
# Epoch 124/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 192ms/step - loss: 2.5075 - val_loss: 2.5061
# Epoch 125/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.4927 - val_loss: 2.4908
# Epoch 126/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 2.4770 - val_loss: 2.4755
# Epoch 127/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 2.4605 - val_loss: 2.4591
# Epoch 128/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 2.4459 - val_loss: 2.4446
# Epoch 129/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 2.4312 - val_loss: 2.4297
# Epoch 130/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 2.4156 - val_loss: 2.4146
# Epoch 131/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.4010 - val_loss: 2.3998
# Epoch 132/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 2.3870 - val_loss: 2.3859
# Epoch 133/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 2.3709 - val_loss: 2.3704
# Epoch 134/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 2.3560 - val_loss: 2.3550
# Epoch 135/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 2.3420 - val_loss: 2.3400
# Epoch 136/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 2.3270 - val_loss: 2.3243
# Epoch 137/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 2.3124 - val_loss: 2.3084
# Epoch 138/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 2.2985 - val_loss: 2.2939
# Epoch 139/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 2.2835 - val_loss: 2.2798
# Epoch 140/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step - loss: 2.2689 - val_loss: 2.2665
# Epoch 141/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 2.2545 - val_loss: 2.2502
# Epoch 142/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.2406 - val_loss: 2.2351
# Epoch 143/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 2.2268 - val_loss: 2.2206
# Epoch 144/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 2.2116 - val_loss: 2.2074
# Epoch 145/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 2.1978 - val_loss: 2.1937
# Epoch 146/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 2.1837 - val_loss: 2.1786
# Epoch 147/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 2.1690 - val_loss: 2.1633
# Epoch 148/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 2.1562 - val_loss: 2.1501
# Epoch 149/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 2.1425 - val_loss: 2.1371
# Epoch 150/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 2.1286 - val_loss: 2.1237
# Epoch 151/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 2.1139 - val_loss: 2.1095
# Epoch 152/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 2.1009 - val_loss: 2.0954
# Epoch 153/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - loss: 2.0872 - val_loss: 2.0808
# Epoch 154/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 2.0736 - val_loss: 2.0665
# Epoch 155/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 2.0601 - val_loss: 2.0531
# Epoch 156/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 2.0463 - val_loss: 2.0400
# Epoch 157/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 2.0326 - val_loss: 2.0268
# Epoch 158/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 2.0201 - val_loss: 2.0132
# Epoch 159/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 237ms/step - loss: 2.0065 - val_loss: 1.9999
# Epoch 160/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 1.9931 - val_loss: 1.9862
# Epoch 161/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - loss: 1.9798 - val_loss: 1.9727
# Epoch 162/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.9676 - val_loss: 1.9598
# Epoch 163/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 1.9541 - val_loss: 1.9465
# Epoch 164/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.9413 - val_loss: 1.9329
# Epoch 165/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 1.9286 - val_loss: 1.9194
# Epoch 166/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.9148 - val_loss: 1.9071
# Epoch 167/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 1.9027 - val_loss: 1.8949
# Epoch 168/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 1.8893 - val_loss: 1.8817
# Epoch 169/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 1.8778 - val_loss: 1.8687
# Epoch 170/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 1.8649 - val_loss: 1.8567
# Epoch 171/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 1.8520 - val_loss: 1.8435
# Epoch 172/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.8387 - val_loss: 1.8297
# Epoch 173/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.8270 - val_loss: 1.8176
# Epoch 174/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 1.8149 - val_loss: 1.8055
# Epoch 175/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 1.8025 - val_loss: 1.7936
# Epoch 176/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 1.7904 - val_loss: 1.7813
# Epoch 177/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 1.7785 - val_loss: 1.7680
# Epoch 178/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 1.7665 - val_loss: 1.7560
# Epoch 179/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 1.7536 - val_loss: 1.7439
# Epoch 180/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 220ms/step - loss: 1.7421 - val_loss: 1.7317
# Epoch 181/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 1.7297 - val_loss: 1.7202
# Epoch 182/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 1.7176 - val_loss: 1.7086
# Epoch 183/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.7059 - val_loss: 1.6958
# Epoch 184/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 1.6945 - val_loss: 1.6845
# Epoch 185/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 1.6832 - val_loss: 1.6729
# Epoch 186/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.6707 - val_loss: 1.6609
# Epoch 187/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - loss: 1.6590 - val_loss: 1.6487
# Epoch 188/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - loss: 1.6478 - val_loss: 1.6368
# Epoch 189/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 1.6362 - val_loss: 1.6265
# Epoch 190/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 1.6251 - val_loss: 1.6145
# Epoch 191/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 1.6129 - val_loss: 1.6029
# Epoch 192/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 1.6019 - val_loss: 1.5916
# Epoch 193/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.5908 - val_loss: 1.5809
# Epoch 194/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 1.5791 - val_loss: 1.5688
# Epoch 195/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - loss: 1.5686 - val_loss: 1.5570
# Epoch 196/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 1.5571 - val_loss: 1.5457
# Epoch 197/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 1.5464 - val_loss: 1.5348
# Epoch 198/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 222ms/step - loss: 1.5347 - val_loss: 1.5244
# Epoch 199/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - loss: 1.5236 - val_loss: 1.5134
# Epoch 200/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 193ms/step - loss: 1.5130 - val_loss: 1.5025
# Epoch 201/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - loss: 1.5025 - val_loss: 1.4916
# Epoch 202/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 1.4914 - val_loss: 1.4809
# Epoch 203/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - loss: 1.4805 - val_loss: 1.4697
# Epoch 204/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 1.4701 - val_loss: 1.4585
# Epoch 205/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 1.4595 - val_loss: 1.4481
# Epoch 206/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 1.4491 - val_loss: 1.4380
# Epoch 207/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 1.4383 - val_loss: 1.4271
# Epoch 208/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - loss: 1.4277 - val_loss: 1.4165
# Epoch 209/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 1.4170 - val_loss: 1.4063
# Epoch 210/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 1.4073 - val_loss: 1.3962
# Epoch 211/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 1.3968 - val_loss: 1.3858
# Epoch 212/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 1.3859 - val_loss: 1.3751
# Epoch 213/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 1.3763 - val_loss: 1.3651
# Epoch 214/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 1.3663 - val_loss: 1.3549
# Epoch 215/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 1.3561 - val_loss: 1.3452
# Epoch 216/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.3461 - val_loss: 1.3349
# Epoch 217/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 1.3357 - val_loss: 1.3250
# Epoch 218/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 1.3256 - val_loss: 1.3149
# Epoch 219/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 1.3161 - val_loss: 1.3052
# Epoch 220/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 220ms/step - loss: 1.3063 - val_loss: 1.2954
# Epoch 221/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 1.2961 - val_loss: 1.2855
# Epoch 222/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 1.2867 - val_loss: 1.2760
# Epoch 223/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 1.2771 - val_loss: 1.2663
# Epoch 224/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.2667 - val_loss: 1.2566
# Epoch 225/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 1.2577 - val_loss: 1.2470
# Epoch 226/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 1.2484 - val_loss: 1.2378
# Epoch 227/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 1.2390 - val_loss: 1.2281
# Epoch 228/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - loss: 1.2295 - val_loss: 1.2193
# Epoch 229/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 1.2201 - val_loss: 1.2094
# Epoch 230/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 219ms/step - loss: 1.2109 - val_loss: 1.2001
# Epoch 231/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 193ms/step - loss: 1.2014 - val_loss: 1.1910
# Epoch 232/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 1.1920 - val_loss: 1.1817
# Epoch 233/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 1.1833 - val_loss: 1.1729
# Epoch 234/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 1.1735 - val_loss: 1.1636
# Epoch 235/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 1.1647 - val_loss: 1.1548
# Epoch 236/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 1.1556 - val_loss: 1.1454
# Epoch 237/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 1.1470 - val_loss: 1.1364
# Epoch 238/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.1379 - val_loss: 1.1275
# Epoch 239/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 1.1294 - val_loss: 1.1187
# Epoch 240/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 1.1208 - val_loss: 1.1099
# Epoch 241/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 1.1111 - val_loss: 1.1013
# Epoch 242/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 1.1026 - val_loss: 1.0924
# Epoch 243/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 1.0941 - val_loss: 1.0838
# Epoch 244/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 1.0854 - val_loss: 1.0752
# Epoch 245/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 1.0767 - val_loss: 1.0666
# Epoch 246/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 1.0679 - val_loss: 1.0582
# Epoch 247/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 1.0597 - val_loss: 1.0497
# Epoch 248/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 1.0512 - val_loss: 1.0414
# Epoch 249/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 1.0429 - val_loss: 1.0330
# Epoch 250/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 1.0341 - val_loss: 1.0248
# Epoch 251/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 1.0261 - val_loss: 1.0164
# Epoch 252/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 252ms/step - loss: 1.0175 - val_loss: 1.0081
# Epoch 253/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 1.0093 - val_loss: 1.0001
# Epoch 254/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step - loss: 1.0013 - val_loss: 0.9919
# Epoch 255/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 0.9930 - val_loss: 0.9838
# Epoch 256/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 192ms/step - loss: 0.9849 - val_loss: 0.9757
# Epoch 257/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.9772 - val_loss: 0.9677
# Epoch 258/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - loss: 0.9695 - val_loss: 0.9598
# Epoch 259/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 242ms/step - loss: 0.9619 - val_loss: 0.9519
# Epoch 260/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.9535 - val_loss: 0.9441
# Epoch 261/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.9456 - val_loss: 0.9363
# Epoch 262/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.9375 - val_loss: 0.9285
# Epoch 263/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.9301 - val_loss: 0.9208
# Epoch 264/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.9223 - val_loss: 0.9133
# Epoch 265/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.9148 - val_loss: 0.9056
# Epoch 266/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.9071 - val_loss: 0.8980
# Epoch 267/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.8994 - val_loss: 0.8904
# Epoch 268/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.8917 - val_loss: 0.8829
# Epoch 269/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.8843 - val_loss: 0.8756
# Epoch 270/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.8768 - val_loss: 0.8681
# Epoch 271/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.8693 - val_loss: 0.8608
# Epoch 272/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 0.8625 - val_loss: 0.8535
# Epoch 273/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.8550 - val_loss: 0.8462
# Epoch 274/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.8476 - val_loss: 0.8390
# Epoch 275/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.8404 - val_loss: 0.8319
# Epoch 276/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.8330 - val_loss: 0.8251
# Epoch 277/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.8259 - val_loss: 0.8182
# Epoch 278/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 0.8189 - val_loss: 0.8105
# Epoch 279/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.8120 - val_loss: 0.8035
# Epoch 280/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 0.8048 - val_loss: 0.7970
# Epoch 281/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 245ms/step - loss: 0.7982 - val_loss: 0.7896
# Epoch 282/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.7910 - val_loss: 0.7829
# Epoch 283/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.7840 - val_loss: 0.7760
# Epoch 284/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.7772 - val_loss: 0.7692
# Epoch 285/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 0.7706 - val_loss: 0.7628
# Epoch 286/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.7637 - val_loss: 0.7566
# Epoch 287/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.7570 - val_loss: 0.7493
# Epoch 288/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 0.7505 - val_loss: 0.7432
# Epoch 289/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 0.7440 - val_loss: 0.7368
# Epoch 290/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 0.7376 - val_loss: 0.7300
# Epoch 291/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - loss: 0.7306 - val_loss: 0.7232
# Epoch 292/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 0.7243 - val_loss: 0.7173
# Epoch 293/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 0.7175 - val_loss: 0.7105
# Epoch 294/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - loss: 0.7116 - val_loss: 0.7037
# Epoch 295/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - loss: 0.7048 - val_loss: 0.6975
# Epoch 296/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - loss: 0.6988 - val_loss: 0.6912
# Epoch 297/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 218ms/step - loss: 0.6926 - val_loss: 0.6852
# Epoch 298/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.6858 - val_loss: 0.6788
# Epoch 299/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.6798 - val_loss: 0.6736
# Epoch 300/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 223ms/step - loss: 0.6738 - val_loss: 0.6664
# Epoch 301/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 0.6672 - val_loss: 0.6602
# Epoch 302/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.6615 - val_loss: 0.6551
# Epoch 303/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.6555 - val_loss: 0.6483
# Epoch 304/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.6491 - val_loss: 0.6424
# Epoch 305/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 248ms/step - loss: 0.6429 - val_loss: 0.6375
# Epoch 306/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 248ms/step - loss: 0.6373 - val_loss: 0.6313
# Epoch 307/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.6316 - val_loss: 0.6250
# Epoch 308/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.6260 - val_loss: 0.6197
# Epoch 309/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.6204 - val_loss: 0.6134
# Epoch 310/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - loss: 0.6136 - val_loss: 0.6079
# Epoch 311/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - loss: 0.6083 - val_loss: 0.6024
# Epoch 312/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - loss: 0.6029 - val_loss: 0.5970
# Epoch 313/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 0.5972 - val_loss: 0.5914
# Epoch 314/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 225ms/step - loss: 0.5914 - val_loss: 0.5849
# Epoch 315/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - loss: 0.5860 - val_loss: 0.5797
# Epoch 316/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - loss: 0.5800 - val_loss: 0.5748
# Epoch 317/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.5751 - val_loss: 0.5687
# Epoch 318/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - loss: 0.5692 - val_loss: 0.5633
# Epoch 319/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - loss: 0.5634 - val_loss: 0.5579
# Epoch 320/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - loss: 0.5584 - val_loss: 0.5520
# Epoch 321/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step - loss: 0.5533 - val_loss: 0.5467
# Epoch 322/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - loss: 0.5477 - val_loss: 0.5423
# Epoch 323/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - loss: 0.5426 - val_loss: 0.5385
# Epoch 324/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 299ms/step - loss: 0.5371 - val_loss: 0.5317
# Epoch 325/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - loss: 0.5315 - val_loss: 0.5260
# Epoch 326/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 329ms/step - loss: 0.5268 - val_loss: 0.5212
# Epoch 327/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - loss: 0.5213 - val_loss: 0.5161
# Epoch 328/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 248ms/step - loss: 0.5166 - val_loss: 0.5106
# Epoch 329/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 319ms/step - loss: 0.5116 - val_loss: 0.5063
# Epoch 330/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - loss: 0.5063 - val_loss: 0.5011
# Epoch 331/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 262ms/step - loss: 0.5015 - val_loss: 0.4962
# Epoch 332/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.4964 - val_loss: 0.4909
# Epoch 333/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.4917 - val_loss: 0.4862
# Epoch 334/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 235ms/step - loss: 0.4867 - val_loss: 0.4820
# Epoch 335/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 0.4816 - val_loss: 0.4767
# Epoch 336/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 0.4772 - val_loss: 0.4712
# Epoch 337/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.4722 - val_loss: 0.4673
# Epoch 338/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 0.4672 - val_loss: 0.4617
# Epoch 339/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 0.4628 - val_loss: 0.4573
# Epoch 340/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.4585 - val_loss: 0.4528
# Epoch 341/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.4528 - val_loss: 0.4488
# Epoch 342/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - loss: 0.4488 - val_loss: 0.4440
# Epoch 343/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.4439 - val_loss: 0.4386
# Epoch 344/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 316ms/step - loss: 0.4397 - val_loss: 0.4346
# Epoch 345/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - loss: 0.4350 - val_loss: 0.4301
# Epoch 346/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 307ms/step - loss: 0.4306 - val_loss: 0.4256
# Epoch 347/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - loss: 0.4263 - val_loss: 0.4217
# Epoch 348/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.4217 - val_loss: 0.4170
# Epoch 349/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.4173 - val_loss: 0.4131
# Epoch 350/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 0.4134 - val_loss: 0.4088
# Epoch 351/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 210ms/step - loss: 0.4089 - val_loss: 0.4049
# Epoch 352/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.4048 - val_loss: 0.4001
# Epoch 353/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 0.4001 - val_loss: 0.3966
# Epoch 354/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - loss: 0.3962 - val_loss: 0.3913
# Epoch 355/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 324ms/step - loss: 0.3917 - val_loss: 0.3888
# Epoch 356/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 316ms/step - loss: 0.3879 - val_loss: 0.3834
# Epoch 357/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 341ms/step - loss: 0.3835 - val_loss: 0.3789
# Epoch 358/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 334ms/step - loss: 0.3795 - val_loss: 0.3755
# Epoch 359/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 316ms/step - loss: 0.3757 - val_loss: 0.3714
# Epoch 360/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - loss: 0.3715 - val_loss: 0.3674
# Epoch 361/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 21s 325ms/step - loss: 0.3679 - val_loss: 0.3636
# Epoch 362/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 339ms/step - loss: 0.3637 - val_loss: 0.3597
# Epoch 363/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - loss: 0.3596 - val_loss: 0.3568
# Epoch 364/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.3558 - val_loss: 0.3519
# Epoch 365/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.3518 - val_loss: 0.3475
# Epoch 366/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - loss: 0.3482 - val_loss: 0.3441
# Epoch 367/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.3444 - val_loss: 0.3403
# Epoch 368/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - loss: 0.3411 - val_loss: 0.3365
# Epoch 369/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - loss: 0.3369 - val_loss: 0.3344
# Epoch 370/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - loss: 0.3332 - val_loss: 0.3291
# Epoch 371/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 0.3296 - val_loss: 0.3257
# Epoch 372/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - loss: 0.3257 - val_loss: 0.3217
# Epoch 373/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 234ms/step - loss: 0.3217 - val_loss: 0.3191
# Epoch 374/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step - loss: 0.3185 - val_loss: 0.3150
# Epoch 375/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 297ms/step - loss: 0.3147 - val_loss: 0.3114
# Epoch 376/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 331ms/step - loss: 0.3117 - val_loss: 0.3087
# Epoch 377/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - loss: 0.3076 - val_loss: 0.3040
# Epoch 378/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 328ms/step - loss: 0.3043 - val_loss: 0.3015
# Epoch 379/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 342ms/step - loss: 0.3009 - val_loss: 0.2982
# Epoch 380/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - loss: 0.2976 - val_loss: 0.2950
# Epoch 381/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 12s 339ms/step - loss: 0.2940 - val_loss: 0.2910
# Epoch 382/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 310ms/step - loss: 0.2906 - val_loss: 0.2885
# Epoch 383/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 297ms/step - loss: 0.2874 - val_loss: 0.2840
# Epoch 384/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - loss: 0.2839 - val_loss: 0.2822
# Epoch 385/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.2806 - val_loss: 0.2772
# Epoch 386/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - loss: 0.2777 - val_loss: 0.2765
# Epoch 387/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 0.2752 - val_loss: 0.2727
# Epoch 388/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.2716 - val_loss: 0.2685
# Epoch 389/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step - loss: 0.2683 - val_loss: 0.2653
# Epoch 390/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.2652 - val_loss: 0.2624
# Epoch 391/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.2622 - val_loss: 0.2587
# Epoch 392/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.2589 - val_loss: 0.2558
# Epoch 393/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 225ms/step - loss: 0.2557 - val_loss: 0.2527
# Epoch 394/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.2524 - val_loss: 0.2503
# Epoch 395/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.2496 - val_loss: 0.2461
# Epoch 396/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.2469 - val_loss: 0.2448
# Epoch 397/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.2438 - val_loss: 0.2414
# Epoch 398/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.2404 - val_loss: 0.2384
# Epoch 399/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.2383 - val_loss: 0.2351
# Epoch 400/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.2351 - val_loss: 0.2327
# Epoch 401/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.2321 - val_loss: 0.2295
# Epoch 402/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - loss: 0.2293 - val_loss: 0.2266
# Epoch 403/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.2266 - val_loss: 0.2252
# Epoch 404/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.2238 - val_loss: 0.2212
# Epoch 405/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - loss: 0.2208 - val_loss: 0.2192
# Epoch 406/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.2182 - val_loss: 0.2173
# Epoch 407/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - loss: 0.2157 - val_loss: 0.2143
# Epoch 408/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - loss: 0.2127 - val_loss: 0.2101
# Epoch 409/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 234ms/step - loss: 0.2102 - val_loss: 0.2084
# Epoch 410/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 0.2079 - val_loss: 0.2063
# Epoch 411/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.2053 - val_loss: 0.2029
# Epoch 412/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.2025 - val_loss: 0.2019
# Epoch 413/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.2000 - val_loss: 0.2010
# Epoch 414/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - loss: 0.1977 - val_loss: 0.1963
# Epoch 415/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.1951 - val_loss: 0.1951
# Epoch 416/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.1926 - val_loss: 0.1918
# Epoch 417/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.1902 - val_loss: 0.1889
# Epoch 418/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.1879 - val_loss: 0.1856
# Epoch 419/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 234ms/step - loss: 0.1853 - val_loss: 0.1835
# Epoch 420/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - loss: 0.1829 - val_loss: 0.1811
# Epoch 421/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step - loss: 0.1807 - val_loss: 0.1801
# Epoch 422/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - loss: 0.1782 - val_loss: 0.1791
# Epoch 423/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - loss: 0.1760 - val_loss: 0.1736
# Epoch 424/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.1735 - val_loss: 0.1734
# Epoch 425/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 0.1717 - val_loss: 0.1705
# Epoch 426/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.1695 - val_loss: 0.1685
# Epoch 427/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - loss: 0.1672 - val_loss: 0.1662
# Epoch 428/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - loss: 0.1653 - val_loss: 0.1642
# Epoch 429/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step - loss: 0.1626 - val_loss: 0.1610
# Epoch 430/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - loss: 0.1606 - val_loss: 0.1607
# Epoch 431/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step - loss: 0.1585 - val_loss: 0.1577
# Epoch 432/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.1563 - val_loss: 0.1566
# Epoch 433/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.1538 - val_loss: 0.1533
# Epoch 434/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.1525 - val_loss: 0.1515
# Epoch 435/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.1500 - val_loss: 0.1498
# Epoch 436/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 0.1478 - val_loss: 0.1460
# Epoch 437/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.1465 - val_loss: 0.1448
# Epoch 438/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.1446 - val_loss: 0.1434
# Epoch 439/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.1422 - val_loss: 0.1420
# Epoch 440/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - loss: 0.1407 - val_loss: 0.1392
# Epoch 441/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - loss: 0.1386 - val_loss: 0.1373
# Epoch 442/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.1362 - val_loss: 0.1360
# Epoch 443/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.1347 - val_loss: 0.1334
# Epoch 444/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.1326 - val_loss: 0.1317
# Epoch 445/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.1305 - val_loss: 0.1322
# Epoch 446/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.1294 - val_loss: 0.1303
# Epoch 447/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.1276 - val_loss: 0.1264
# Epoch 448/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.1256 - val_loss: 0.1232
# Epoch 449/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.1243 - val_loss: 0.1217
# Epoch 450/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 216ms/step - loss: 0.1221 - val_loss: 0.1216
# Epoch 451/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 225ms/step - loss: 0.1204 - val_loss: 0.1192
# Epoch 452/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 220ms/step - loss: 0.1188 - val_loss: 0.1168
# Epoch 453/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 265ms/step - loss: 0.1169 - val_loss: 0.1198
# Epoch 454/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.1152 - val_loss: 0.1147
# Epoch 455/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 0.1137 - val_loss: 0.1142
# Epoch 456/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.1124 - val_loss: 0.1138
# Epoch 457/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - loss: 0.1106 - val_loss: 0.1096
# Epoch 458/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.1091 - val_loss: 0.1107
# Epoch 459/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.1074 - val_loss: 0.1086
# Epoch 460/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.1064 - val_loss: 0.1057
# Epoch 461/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.1043 - val_loss: 0.1046
# Epoch 462/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.1029 - val_loss: 0.1020
# Epoch 463/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 464/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 226ms/step - loss: 0.0999 - val_loss: 0.0989
# Epoch 465/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.0982 - val_loss: 0.0971
# Epoch 466/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 212ms/step - loss: 0.0969 - val_loss: 0.0957
# Epoch 467/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.0958 - val_loss: 0.0954
# Epoch 468/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 0.0944 - val_loss: 0.0943
# Epoch 469/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.0930 - val_loss: 0.0927
# Epoch 470/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - loss: 0.0913 - val_loss: 0.0931
# Epoch 471/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 224ms/step - loss: 0.0901 - val_loss: 0.0909
# Epoch 472/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - loss: 0.0893 - val_loss: 0.0900
# Epoch 473/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.0875 - val_loss: 0.0883
# Epoch 474/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.0861 - val_loss: 0.0854
# Epoch 475/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.0847 - val_loss: 0.0860
# Epoch 476/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 220ms/step - loss: 0.0837 - val_loss: 0.0844
# Epoch 477/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.0823 - val_loss: 0.0824
# Epoch 478/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.0810 - val_loss: 0.0817
# Epoch 479/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.0795 - val_loss: 0.0825
# Epoch 480/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.0785 - val_loss: 0.0798
# Epoch 481/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.0773 - val_loss: 0.0787
# Epoch 482/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.0766 - val_loss: 0.0761
# Epoch 483/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - loss: 0.0749 - val_loss: 0.0758
# Epoch 484/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 0.0741 - val_loss: 0.0740
# Epoch 485/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.0732 - val_loss: 0.0740
# Epoch 486/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 218ms/step - loss: 0.0716 - val_loss: 0.0728
# Epoch 487/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.0708 - val_loss: 0.0712
# Epoch 488/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - loss: 0.0695 - val_loss: 0.0704
# Epoch 489/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.0687 - val_loss: 0.0701
# Epoch 490/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 0.0680 - val_loss: 0.0681
# Epoch 491/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 0.0664 - val_loss: 0.0685
# Epoch 492/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - loss: 0.0657 - val_loss: 0.0657
# Epoch 493/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.0642 - val_loss: 0.0656
# Epoch 494/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.0634 - val_loss: 0.0632
# Epoch 495/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - loss: 0.0628 - val_loss: 0.0639
# Epoch 496/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - loss: 0.0620 - val_loss: 0.0624
# Epoch 497/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.0606 - val_loss: 0.0600
# Epoch 498/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 0.0600 - val_loss: 0.0596
# Epoch 499/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 235ms/step - loss: 0.0589 - val_loss: 0.0580
# Epoch 500/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 244ms/step - loss: 0.0580 - val_loss: 0.0579

# %%
predictions=final_model.predict(X_scaled)

predictions_unscaled=scaler_y.inverse_transform(predictions)
predictions_unscaled=np.exp(predictions_unscaled)

print("RMSE:",root_mean_squared_error(predictions_unscaled,df1['Close'][365:]))
print("MSE:",mean_squared_error(predictions_unscaled,df1['Close'][365:]))
print("R-squared value:",r2_score(predictions_unscaled,df1['Close'][365:]))
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step
# RMSE: 16.16275978559478
# MSE: 261.23480388683976
# R-squared value: 0.9125933793396821

# %%
#original values
pd.DataFrame({"Actual":df1['Close'][-30:].values,"Predictions":predictions_unscaled.ravel()[-30:]})
# Out:
#         Actual  Predictions
# 0   265.760010   260.083008
# 1   267.100006   261.211395
# 2   266.290009   262.361725
# 3   263.190002   263.532043
# 4   262.010010   264.714996
# 5   261.779999   265.908875
# 6   266.369995   267.112122
# 7   264.290009   268.323303
# 8   267.839996   269.537842
# 9   267.250000   270.758118
# 10  264.160004   271.986115
# 11  259.450012   273.216339
# 12  261.739990   274.439392
# 13  265.579987   275.655548
# 14  270.709991   276.866821
# 15  266.920013   278.078369
# 16  268.480011   279.285919
# 17  270.769989   280.488647
# 18  271.459991   281.691223
# 19  275.149994   282.894867
# 20  279.859985   284.101532
# 21  280.410004   285.315063
# 22  279.739990   286.538574
# 23  280.019989   287.770355
# 24  279.440002   289.014465
# 25  284.000000   290.268402
# 26  284.269989   291.531616
# 27  289.910004   292.801086
# 28  289.799988   294.086121
# 29  291.519989   295.390228

# %%
plt.figure(figsize=(14,6))
sns.lineplot(y=df1['Close'][365:],x=range(len(df1['Close'][365:])), label='Actual_value', color='green')
sns.lineplot(y=predictions_unscaled.ravel(),x=range(len(predictions_unscaled)), label='Predicted_value', color='brown')
plt.title('Model prediction vs actual values analysis')
plt.legend()
plt.show()

# %% [markdown]
# # Forecasting for next 30 days

# %%
last_sequence=X_scaled[-1].reshape(1,-1)

last_sequence=np.expand_dims(last_sequence, -1)
steps=30
forecasts=[]
for _ in range(steps):
    next_pred=final_model.predict(last_sequence)[0][0]
    forecasts.append(next_pred)
    next_input = np.array(next_pred).reshape(1, 1, 1)
    last_sequence=np.append(last_sequence[:,1:,:],next_input,axis=1)

# Reverse the transformations
forecasts_unscaled=scaler_y.inverse_transform(np.array(forecasts).reshape(-1, 1))
forecasts_unscaled=np.exp(forecasts_unscaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step

# %%
forecasts_unscaled
# Out:
# array([[297.05005],
#        [297.48788],
#        [297.92755],
#        [298.36996],
#        [298.81635],
#        [299.26694],
#        [299.72235],
#        [300.18292],
#        [300.64877],
#        [301.11978],
#        [301.59598],
#        [302.07727],
#        [302.5637 ],
#        [303.05518],
#        [303.5515 ],
#        [304.05292],
#        [304.55902],
#        [305.06992],
#        [305.58502],
#        [306.1051 ],
#        [306.62924],
#        [307.15768],
#        [307.69052],
#        [308.2274 ],
#        [308.7686 ],
#        [309.31354],
#        [309.8624 ],
#        [310.41534],
#        [310.97226],
#        [311.5325 ]], dtype=float32)

# %%
import pickle
with open(r"C:\Users\sahub\Desktop\P461_stock_analysis\lstm_model.pkl", "rb") as file:
    final_model=pickle.load(file)

# %%
original_index = np.arange(1, len(df1['Close'][365:].ravel()) + 1)

forecast_index = np.arange(len(predictions_unscaled.ravel()) + 1, 
                            len(predictions_unscaled.ravel()) + len(forecasts_unscaled) + 1)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(original_index, df1['Close'][365:].ravel(), label='actual values', color='blue')

plt.plot(original_index, predictions_unscaled, label='Predictions', color='red')

plt.plot(forecast_index,forecasts_unscaled, label=f'{steps} days Forecast', color='green', linestyle='--')

# Adding details
plt.xlabel('Time')
plt.ylabel('Values')
plt.title('Actual values, Predictions and 30-Day Forecast')
plt.legend()
plt.show()

# %%
import pickle
with open("lstm_model.pkl", 'wb') as file:
    pickle.dump(final_model,file)

with open("scaler", 'wb') as file:
    pickle.dump(scaler_y, file)

with open ("X_scaled", 'wb') as file:
    pickle.dump(X_scaled, file)
